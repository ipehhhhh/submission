# %% [markdown]
# # Proyek Analisis Data: [Air Quality Dataset]
# - **Nama:** Syarifah Alexandria
# - **Email:** syarifah.alex@student.ub.ac.od
# - **ID Dicoding:** andriia

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana perubahan kondisi kualitas udara berdasarkan data PM10 pada setiap bulannya di tahun 2015 yang terjadi di Stasiun Changping?
# - Bagaimana perbandingan kadar karbon monoksida pada udara di Stasiun Changping dan Stasiun Dongsi
# - Bagaimana hubungan antara tingkat polusi udara (diwakili oleh PM2.5 dan PM10) dengan suhu udara (TEMP) pada bulan November 2014 hingga Januari 2015 pada Stasiun Dongsi

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
pip install numpy pandas scipy matplotlib seaborn streamlit
# Out:
# Requirement already satisfied: numpy in c:\users\syari\appdata\roaming\python\python311\site-packages (1.26.2)
# Requirement already satisfied: pandas in c:\users\syari\appdata\roaming\python\python311\site-packages (2.1.3)
# Requirement already satisfied: scipy in c:\users\syari\appdata\roaming\python\python311\site-packages (1.11.4)
# Requirement already satisfied: matplotlib in c:\users\syari\appdata\roaming\python\python311\site-packages (3.8.2)
# Requirement already satisfied: seaborn in c:\users\syari\appdata\roaming\python\python311\site-packages (0.13.0)
# Requirement already satisfied: streamlit in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (1.31.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\syari\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\syari\appdata\roaming\python\python311\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=8 in c:\users\syari\appdata\roaming\python\python311\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (7.0.1)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (15.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (4.6.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\syari\appdata\roaming\python\python311\site-packages (from streamlit) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\syari\appdata\roaming\python\python311\site-packages (from streamlit) (6.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (4.0.0)
# Requirement already satisfied: jinja2 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: colorama in c:\users\syari\appdata\roaming\python\python311\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\syari\appdata\roaming\python\python311\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\syari\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\syari\appdata\roaming\python\python311\site-packages (from rich<14,>=10.14.0->streamlit) (2.14.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\syari\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import calendar 
import os
from IPython.display import display

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# 1. Membaca data csv dari Stasiun Changping dan menyimpannya sebagai dataframe Changping_df

# %%
Changping_df = pd.read_csv(r"C:\Users\syari\Document\KULIAH\Semester_6_BANGKIT\submission\data\PRSA_Data_Changping_20130301-20170228.csv")
Changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %% [markdown]
# 2. Membaca data csv dari Stasiun Changping dan menyimpannya sebagai dataframe Dongsi_df

# %%
Dongsi_df = pd.read_csv(r"C:\Users\syari\Document\KULIAH\Semester_6_BANGKIT\submission\data\PRSA_Data_Dongsi_20130301-20170228.csv")
Dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Assessing Data from Changping Station

# %% [markdown]
# 1. Mendapatkan informasi jumlah data yang ada pada setiap fitur dan tipe datanya di dataframe Stasiun Changping

# %%
Changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# 2. Mendapatkan informasi jumlah data yang bernilai null pada setiap features data Stasiun Changping

# %%
Changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %% [markdown]
# 3. Mendapatkan informasi jumlah data yang terduplikasi pada data Stasiun Changping

# %%
print("Jumlah duplikasi: ", Changping_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# 4. Mendapatkan informasi sum dari data, mean, standar deviasi, etc dari data Stasiun Changping

# %%
Changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# std       72.326926     83.441738     20.975331     29.519796   1103.056282
# min        2.000000      2.000000      0.285600      1.847700    100.000000
# 25%       18.000000     34.000000      2.000000     22.000000    500.000000
# 50%       46.000000     72.000000      7.000000     36.000000    800.000000
# 75%      100.000000    131.000000     18.000000     60.358200   1400.000000
# max      882.000000    999.000000    310.000000    226.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34460.000000  35011.000000  35014.000000  35011.000000  35013.000000
# mean      57.940003     13.686111   1007.760278      1.505495      0.060366
# std       54.316674     11.365313     10.225664     13.822099      0.752899
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       15.636600      3.400000    999.300000    -10.200000      0.000000
# 50%       46.000000     14.700000   1007.400000      1.800000      0.000000
# 75%       80.000000     23.300000   1016.000000     14.200000      0.000000
# max      429.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35021.000000
# mean       1.853836
# std        1.309808
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000

# %% [markdown]
# #### Assessing Data from Dongsi Station

# %% [markdown]
# 1. Mendapatkan informasi jumlah data yang ada pada setiap fitur dan tipe datanya di dataframe Stasiun Dongsi

# %%
Dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# 2. Mendapatkan informasi jumlah data yang bernilai null pada setiap features data Stasiun Dongsi

# %%
Dongsi_df.isnull().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# 3. Mendapatkan informasi jumlah data yang terduplikasi pada data Stasiun Dongsi

# %%
print("Jumlah duplikasi: ", Dongsi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# 4. Mendapatkan informasi sum dari data, mean, standar deviasi, etc dari data Stasiun Dongsi

# %%
Dongsi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# std       86.575127     98.219860     22.905655     33.959230   1191.305887
# min        3.000000      2.000000      0.285600      2.000000    100.000000
# 25%       22.000000     38.000000      4.000000     27.000000    600.000000
# 50%       61.000000     86.000000     10.000000     47.000000   1000.000000
# 75%      119.000000    151.000000     24.000000     73.000000   1700.000000
# max      737.000000    955.000000    300.000000    258.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34400.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      57.210637     13.671490   1012.547419      2.447535      0.064020
# std       58.033275     11.458418     10.266059     13.810696      0.786282
# min        0.642600    -16.800000    987.100000    -35.300000      0.000000
# 25%       12.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       44.125200     14.600000   1012.200000      3.000000      0.000000
# 75%       81.000000     23.500000   1020.900000     15.000000      0.000000
# max     1071.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Cleaning Data dari Dataframe Changping Station

# %% [markdown]
# 1. Mengisi nilai null pada Stasiun Changping menggunakan metode interpolasi, karena database berbasis waktu

# %%
# Menggunakan metode interpolasi untuk mengisi nilai null
Changping_df = Changping_df.interpolate(method='linear', axis=0).round(2)
# Out:
# C:\Users\syari\AppData\Local\Temp\ipykernel_18188\58354681.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   Changping_df = Changping_df.interpolate(method='linear', axis=0).round(2)

# %%
# Assuming the script is located in the same directory as the CSV file
current_directory = os.getcwd()  # Get the current working directory

# Define the relative path to the directory where you want to save the CSV file
csv_directory = os.path.join(current_directory, "dashboard")

# Create the directory if it doesn't exist
os.makedirs(csv_directory, exist_ok=True)

# Define the relative path to the CSV file
csv_filename = "main_data_Dongsi.csv"
csv_path = os.path.join(csv_directory, csv_filename)

# Save the DataFrame to CSV using the relative path
Changping_df.to_csv(csv_path, index=False)

# Mencetak dataframe yang sudah diisi nilai null
print(Changping_df)
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0
# 1          2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0
# 2          3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0
# 3          4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0
# 4          5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   28.0  47.0   4.0  14.0  300.0  33.0
# 35060  35061  2017      2   28    20   12.0  12.0   3.0  23.0  500.0  64.0
# 35061  35062  2017      2   28    21    7.0  23.0   5.0  17.0  500.0  68.0
# 35062  35063  2017      2   28    22   11.0  20.0   3.0  15.0  500.0  72.0
# 35063  35064  2017      2   28    23   20.0  25.0   6.0  28.0  900.0  54.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 0      -2.3  1020.8 -19.7   0.0    E   0.5  Changping
# 1      -2.5  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2      -3.0  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3      -3.6  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4      -3.5  1022.3 -19.4   0.0    N   2.1  Changping
# ...     ...     ...   ...   ...  ...   ...        ...
# 35059  11.7  1008.9 -13.3   0.0  NNE   1.3  Changping
# 35060  10.9  1009.0 -14.0   0.0    N   2.1  Changping
# 35061   9.5  1009.4 -13.0   0.0    N   1.5  Changping
# 35062   7.8  1009.6 -12.6   0.0   NW   1.4  Changping
# 35063   7.0  1009.4 -12.2   0.0    N   1.9  Changping
#
# [35064 rows x 18 columns]

# %% [markdown]
# 2. Mendapatkan informasi jumlah data yang bernilai null pada setiap features data Stasiun Changping, seluruh data numerik sudah terisi dengan nilai

# %%
Changping_df.isnull().sum()
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         140
# WSPM         0
# station      0
# dtype: int64

# %% [markdown]
# 3. Mendapatkan informasi jumlah value outliers pada Stasiun Changping dengan nilai standar deviasi

# %%
def detect_outliers_std(df, threshold=3):
    outliers = pd.DataFrame()  # DataFrame baru untuk menyimpan outliers
    for col in df.columns:
        if df[col].dtype in ['int64', 'float64']:  # Hanya pilih kolom numerik
            mean = df[col].mean()
            std_dev = df[col].std()
            lower_bound = mean - threshold * std_dev
            upper_bound = mean + threshold * std_dev
            col_outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
            if not col_outliers.empty:
                outliers = pd.concat([outliers, col_outliers])  # Menambahkan outliers ke DataFrame baru
                print("Outlier values for", col, ":", col_outliers[col].tolist())
    return outliers

# Deteksi outlier
outliers_df = detect_outliers_std(Changping_df)

# Mencetak dataframe outliers
print(outliers_df)
# Out:
# Outlier values for PM2.5 : [293.0, 302.0, 312.0, 339.0, 326.0, 290.0, 443.0, 289.0, 298.0, 301.0, 308.0, 374.0, 330.0, 340.0, 349.0, 350.0, 368.0, 403.0, 394.0, 338.0, 379.0, 291.0, 297.0, 310.0, 304.0, 294.0, 381.0, 347.0, 358.0, 289.0, 294.0, 335.0, 360.0, 390.0, 391.0, 375.0, 311.0, 302.0, 304.0, 291.0, 293.0, 298.0, 317.0, 327.0, 322.0, 315.0, 315.0, 319.0, 297.0, 299.0, 291.0, 299.0, 302.0, 322.0, 322.0, 291.0, 307.0, 313.0, 307.0, 289.0, 299.0, 304.0, 300.0, 314.0, 308.0, 294.0, 296.0, 331.0, 330.0, 375.0, 345.0, 325.0, 312.0, 298.0, 305.0, 294.0, 347.0, 370.0, 377.0, 303.0, 290.0, 289.0, 298.0, 313.0, 300.0, 377.0, 423.0, 409.0, 365.0, 352.0, 337.0, 295.0, 307.0, 301.0, 290.0, 293.0, 352.0, 330.0, 313.
#           No  year  month  day  hour  PM2.5   PM10    SO2    NO2      CO  \
# 135      136  2013      3    6    15  293.0  347.0  118.0  160.0  3299.0
# 136      137  2013      3    6    16  302.0  352.0  112.0  158.0  3100.0
# 137      138  2013      3    6    17  312.0  342.0  107.0  141.0  2700.0
# 142      143  2013      3    6    22  339.0  394.0  118.0  148.0  5500.0
# 143      144  2013      3    6    23  326.0  360.0  113.0  140.0  4500.0
# ...      ...   ...    ...  ...   ...    ...    ...    ...    ...     ...
# 34620  34621  2017      2   10    12   12.0   35.0    6.0   16.0   400.0
# 34621  34622  2017      2   10    13    9.0   41.0    6.0   17.0   300.0
# 34790  34791  2017      2   17    14    6.0   25.0    4.0   21.0   400.0
# 34853  34854  2017      2   20     5    3.0   24.0    2.0   11.0   200.0
# 34859  34860  2017      2   20    11    9.0   35.0    7.0   24.0   500.0
#
#          O3  TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 135    81.0  13.6  1001.9  -3.7   0.0  ESE   2.2  Changping
# 136    66.0  13.3  1002.2  -3.9   0.0  ESE   1.6  Changping
# 137    60.0  12.0  1002.7  -3.8   0.0   SE   1.3  Changping
# 142    35.0   4.7  1004.3  -3.6   0.0    E   0.7  Changping
# 143    30.0   4.5  1004.1  -3.3   0.0    S   0.9  Changping
# ...     ...   ...     ...   ...   ...  ...   ...        ...
# 34620  48.0   1.3  1021.2 -21.1   0.0  WNW   6.3  Changping
# 34621  49.0   2.4  1020.0 -20.9   0.0  WNW   5.8  Changping
# 34790  63.0   5.3  1019.8 -22.9   0.0  WNW   6.0  Changping
# 34853  70.0  -1.6  1018.5 -21.1   0.0   NW   6.1  Changping
# 34859  51.0   0.6  1024.8 -21.7   0.0  WNW   5.8  Changping
#
# [4732 rows x 18 columns]

# %% [markdown]
# 4. Menghapus value outlier dari dataframe

# %%
# Fungsi untuk menghapus outlier dari dataframe
def remove_outliers_df(df, outliers_df):
    cleaned_df = df.copy()  # Salin dataframe untuk diubah
    cleaned_df = cleaned_df.drop(outliers_df.index)  # Hapus baris dengan indeks yang sama dengan outliers
    return cleaned_df

# Menghapus outlier dari dataframe Changping_df
Changping_df = remove_outliers_df(Changping_df, outliers_df)

# Mencetak dataframe yang sudah dihapus outlier
print(Changping_df)
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0
# 1          2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0
# 2          3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0
# 3          4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0
# 4          5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   28.0  47.0   4.0  14.0  300.0  33.0
# 35060  35061  2017      2   28    20   12.0  12.0   3.0  23.0  500.0  64.0
# 35061  35062  2017      2   28    21    7.0  23.0   5.0  17.0  500.0  68.0
# 35062  35063  2017      2   28    22   11.0  20.0   3.0  15.0  500.0  72.0
# 35063  35064  2017      2   28    23   20.0  25.0   6.0  28.0  900.0  54.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 0      -2.3  1020.8 -19.7   0.0    E   0.5  Changping
# 1      -2.5  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2      -3.0  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3      -3.6  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4      -3.5  1022.3 -19.4   0.0    N   2.1  Changping
# ...     ...     ...   ...   ...  ...   ...        ...
# 35059  11.7  1008.9 -13.3   0.0  NNE   1.3  Changping
# 35060  10.9  1009.0 -14.0   0.0    N   2.1  Changping
# 35061   9.5  1009.4 -13.0   0.0    N   1.5  Changping
# 35062   7.8  1009.6 -12.6   0.0   NW   1.4  Changping
# 35063   7.0  1009.4 -12.2   0.0    N   1.9  Changping
#
# [31543 rows x 18 columns]

# %% [markdown]
# #### Cleaning Data dari Dataframe Dongsi Station

# %% [markdown]
# 1. Mengisi nilai null pada Stasiun Changping menggunakan metode interpolasi, karena database berbasis waktu

# %%
# Menggunakan metode interpolasi untuk mengisi nilai null
Dongsi_df = Dongsi_df.interpolate(method='linear', axis=0).round(2)
# Out:
# C:\Users\syari\AppData\Local\Temp\ipykernel_18188\3680045640.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   Dongsi_df = Dongsi_df.interpolate(method='linear', axis=0).round(2)

# %%
# Assuming the script is located in the same directory as the CSV file
current_directory = os.getcwd()  # Get the current working directory

# Define the relative path to the directory where you want to save the CSV file
csv_directory = os.path.join(current_directory, "dashboard")

# Create the directory if it doesn't exist
os.makedirs(csv_directory, exist_ok=True)

# Define the relative path to the CSV file
csv_filename = "main_data_Dongsi.csv"
csv_path = os.path.join(csv_directory, csv_filename)

# Save the DataFrame to CSV using the relative path
Dongsi_df.to_csv(csv_path, index=False)

# Mencetak dataframe yang sudah diisi nilai null
print(Dongsi_df)
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    9.0   9.0   3.0  17.0   300.0  89.0
# 1          2  2013      3    1     1    4.0   4.0   3.0  16.0   300.0  88.0
# 2          3  2013      3    1     2    7.0   7.0   4.0  17.0   300.0  60.0
# 3          4  2013      3    1     3    3.0   3.0   5.0  18.0   250.0  72.0
# 4          5  2013      3    1     4    3.0   3.0   7.0  21.5   200.0  84.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 35059  35060  2017      2   28    19   16.0  51.0   3.0  29.0   400.0  73.0
# 35060  35061  2017      2   28    20   18.0  45.0   3.0  43.0   500.0  54.0
# 35061  35062  2017      2   28    21   23.0  58.0   5.0  61.0   700.0  28.0
# 35062  35063  2017      2   28    22   23.0  53.0   9.0  75.0   900.0  15.0
# 35063  35064  2017      2   28    23   30.0  71.0  11.0  87.0  1200.0   4.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# 0      -0.5  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1      -0.7  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2      -1.2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3      -1.4  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4      -1.9  1027.1 -24.5   0.0  NNW   3.2  Dongsi
# ...     ...     ...   ...   ...  ...   ...     ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Dongsi
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Dongsi
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Dongsi
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Dongsi
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Dongsi
#
# [35064 rows x 18 columns]

# %% [markdown]
# 2. Mendapatkan informasi jumlah data yang bernilai null pada setiap features data Stasiun Changping, seluruh data numerik sudah terisi dengan nilai

# %%
Dongsi_df.isnull().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         78
# WSPM        0
# station     0
# dtype: int64

# %% [markdown]
# 3. Mendapatkan informasi jumlah value outliers pada Stasiun Changping dengan nilai standar deviasi

# %%
def detect_outliers_std(df, threshold=3):
    outliers = pd.DataFrame()  # DataFrame baru untuk menyimpan outliers
    for col in df.columns:
        if df[col].dtype in ['int64', 'float64']:  # Hanya pilih kolom numerik
            mean = df[col].mean()
            std_dev = df[col].std()
            lower_bound = mean - threshold * std_dev
            upper_bound = mean + threshold * std_dev
            col_outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
            if not col_outliers.empty:
                outliers = pd.concat([outliers, col_outliers])  # Menambahkan outliers ke DataFrame baru
                print("Outlier values for", col, ":", col_outliers[col].tolist())
    return outliers

# Deteksi outlier
outliers_df = detect_outliers_std(Dongsi_df)

# Mencetak dataframe outliers
print(outliers_df)
# Out:
# Outlier values for PM2.5 : [438.0, 520.0, 488.0, 450.0, 362.0, 355.0, 347.0, 362.0, 404.0, 396.0, 357.0, 373.0, 394.0, 417.0, 441.0, 509.0, 487.0, 430.0, 354.0, 356.0, 347.0, 495.0, 495.0, 485.0, 515.0, 507.0, 487.0, 345.0, 368.0, 390.0, 416.0, 379.0, 365.0, 346.0, 348.0, 358.0, 368.0, 355.0, 351.0, 348.0, 362.0, 378.0, 390.0, 346.0, 345.0, 355.0, 366.0, 395.0, 395.0, 424.0, 413.0, 393.0, 393.0, 386.0, 399.0, 399.0, 397.0, 383.0, 388.0, 401.0, 383.0, 395.0, 390.0, 363.0, 348.0, 359.0, 346.0, 436.0, 500.0, 531.0, 532.0, 553.0, 584.0, 598.0, 593.0, 597.0, 603.0, 590.0, 555.0, 494.0, 494.0, 429.0, 423.0, 440.0, 425.0, 371.0, 399.0, 372.0, 387.0, 364.0, 374.0, 366.0, 504.0, 684.0, 737.0, 679.0, 560.0, 555.0, 490.0, 421.0, 362.0, 395.0, 424.0, 496.0, 485.0, 439.0, 423.0, 416.0, 449.0, 451.0, 473.0, 450.0, 447.0, 444.0, 445.0, 456.0, 432.0, 409.0, 394.0, 370.0, 362.0, 356.0, 361.0, 368.0, 383.0, 394.0, 399.0, 399.0, 375.0, 348.0, 347.0, 354.0, 367.0, 381.0, 395.0, 409.0, 423.0, 437.0, 451.0, 465.0, 479.0, 479.0, 488.0, 477.0, 471.67, 466.33, 461.0, 455.67, 450.33, 445.0, 447.0, 449.0, 456.0, 451.0, 466.0, 466.0, 516.0, 513.0, 485.0, 483.0, 445.0, 347.0, 351.0, 373.0, 385.0, 396.0, 403.0, 412.0, 420.0, 419.0, 402.0, 360.0, 353.0, 345.0, 395.0, 372.0, 351.0, 355.0, 345.0, 347.5, 350.0, 347.0, 370.0, 371.0, 367.0, 357.0, 357.0, 390.0, 403.0, 420.0, 428.0, 444.0, 450.0, 442.0, 445.0, 436
, 6.0, 5.9, 5.8, 5.8, 5.9, 7.1, 6.2, 6.4, 5.9, 5.8, 6.4, 7.7, 6.3, 6.0, 6.9, 9.2, 8.2, 7.2, 6.9, 6.8, 6.2, 6.0, 6.7, 6.3, 6.0, 6.8, 6.8, 6.0, 6.1, 5.9, 6.4, 6.9, 6.7, 6.6, 6.9, 6.2, 7.3, 6.2, 5.9, 7.3, 6.8, 6.3, 8.0, 8.4, 7.9, 7.1, 6.5, 6.0, 8.8, 6.4, 7.4, 6.6, 6.1, 6.4, 6.0, 6.8, 5.9, 7.0, 6.6, 5.8, 6.5, 5.8, 6.1, 5.8, 5.8, 6.3, 5.9, 6.7, 6.6, 6.3, 6.7, 6.4, 6.8, 5.9, 5.9, 7.5, 6.1, 6.0, 5.9, 5.8, 6.6, 6.5, 5.9, 6.3, 7.0, 6.3, 6.3, 7.1, 7.1, 8.1, 6.3, 6.0, 6.0, 7.3, 6.8, 5.9, 6.0, 6.6, 6.3, 5.8, 7.0, 5.8, 6.2, 6.3, 6.1, 6.5, 6.2, 5.9, 5.9, 5.9, 5.8, 6.8, 6.0, 6.1, 6.3, 6.0, 7.0, 5.8, 6.3, 8.9, 6.9, 6.2, 5.9, 5.9, 6.3, 6.2, 6.0, 6.5, 6.6, 6.8, 6.6, 8.6, 8.3, 5.9, 7.2, 6.6, 7.5, 5.9, 6.8, 6.5, 5.8, 6.6, 6.1, 6.0, 6.1, 6.1, 6.8]
#           No  year  month  day  hour  PM2.5   PM10    SO2    NO2      CO  \
# 166      167  2013      3    7    22  438.0  552.0  114.0  258.0  5500.0
# 167      168  2013      3    7    23  520.0  585.0  110.0  249.0  5400.0
# 168      169  2013      3    8     0  488.0  518.0  115.0  241.0  4799.0
# 169      170  2013      3    8     1  450.0  455.0  106.0  232.0  4900.0
# 170      171  2013      3    8     2  362.0  407.0  100.0  226.0  4799.0
# ...      ...   ...    ...  ...   ...    ...    ...    ...    ...     ...
# 34765  34766  2017      2   16    13   16.0   72.0    4.0   21.0   200.0
# 34767  34768  2017      2   16    15   15.0   20.0    2.0   22.0   100.0
# 34840  34841  2017      2   19    16   15.0  209.0    2.0    6.0   200.0
# 34842  34843  2017      2   19    18    8.0  117.0    2.0   10.0   300.0
# 34849  34850  2017      2   20     1    6.0   41.0    2.0    8.0   200.0
#
#           O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# 166    107.0   8.1  1000.1  -0.9   0.0    E   0.8  Dongsi
# 167    107.0   7.0  1000.0  -1.4   0.0   SE   0.4  Dongsi
# 168    107.0   5.4  1000.0  -1.5   0.0  ENE   0.9  Dongsi
# 169    107.0   5.3  1000.2  -1.8   0.0  WNW   0.9  Dongsi
# 170    107.0   4.1   999.9  -2.3   0.0  WNW   0.0  Dongsi
# ...      ...   ...     ...   ...   ...  ...   ...     ...
# 34765   62.0   7.1  1014.9 -13.8   0.0   NE   6.1  Dongsi
# 34767   70.0   6.6  1015.7 -17.5   0.0  ENE   6.0  Dongsi
# 34840   93.0  10.3  1005.2 -21.3   0.0    N   6.1  Dongsi
# 34842   88.0   9.2  1008.8 -20.9   0.0  NNW   6.1  Dongsi
# 34849   80.0   1.5  1020.3 -21.7   0.0  NNE   6.8  Dongsi
#
# [4101 rows x 18 columns]

# %% [markdown]
# 4. Menghapus value outlier dari dataframe

# %%
# Fungsi untuk menghapus outlier dari dataframe
def remove_outliers_df(df, outliers_df):
    cleaned_df = df.copy()  # Salin dataframe untuk diubah
    cleaned_df = cleaned_df.drop(outliers_df.index)  # Hapus baris dengan indeks yang sama dengan outliers
    return cleaned_df

# Menghapus outlier dari dataframe Dongsi_df
Dongsi_df = remove_outliers_df(Dongsi_df, outliers_df)

# Mencetak dataframe yang sudah dihapus outlier
print(Dongsi_df)
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    9.0   9.0   3.0  17.0   300.0  89.0
# 1          2  2013      3    1     1    4.0   4.0   3.0  16.0   300.0  88.0
# 2          3  2013      3    1     2    7.0   7.0   4.0  17.0   300.0  60.0
# 3          4  2013      3    1     3    3.0   3.0   5.0  18.0   250.0  72.0
# 4          5  2013      3    1     4    3.0   3.0   7.0  21.5   200.0  84.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 35059  35060  2017      2   28    19   16.0  51.0   3.0  29.0   400.0  73.0
# 35060  35061  2017      2   28    20   18.0  45.0   3.0  43.0   500.0  54.0
# 35061  35062  2017      2   28    21   23.0  58.0   5.0  61.0   700.0  28.0
# 35062  35063  2017      2   28    22   23.0  53.0   9.0  75.0   900.0  15.0
# 35063  35064  2017      2   28    23   30.0  71.0  11.0  87.0  1200.0   4.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# 0      -0.5  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1      -0.7  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2      -1.2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3      -1.4  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4      -1.9  1027.1 -24.5   0.0  NNW   3.2  Dongsi
# ...     ...     ...   ...   ...  ...   ...     ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Dongsi
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Dongsi
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Dongsi
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Dongsi
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Dongsi
#
# [32230 rows x 18 columns]

# %% [markdown]
# 6. Menyimpan Data yang sudah dibersihkan ke dalam file csv bernama main_data.csv

# %%
# Assuming the script is located in the same directory as the CSV file
current_directory = os.getcwd()  # Get the current working directory

# Define the relative path to the directory where you want to save the CSV file
csv_directory = os.path.join(current_directory, "dashboard")

# Create the directory if it doesn't exist
os.makedirs(csv_directory, exist_ok=True)

# Define the relative path to the CSV file
csv_filename = "main_data.csv"
csv_path = os.path.join(csv_directory, csv_filename)

# Concatenate Changping_df and Dongsi_df
combined_df = pd.concat([Changping_df, Dongsi_df])

# Save the combined DataFrame to CSV using the relative path
combined_df.to_csv(csv_path, index=False)

# Print the combined DataFrame
print(combined_df)
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0  13.0   7.0   300.0  85.0
# 1          2  2013      3    1     1    3.0   3.0   6.0   6.0   300.0  85.0
# 2          3  2013      3    1     2    3.0   3.0  22.0  13.0   400.0  74.0
# 3          4  2013      3    1     3    3.0   6.0  12.0   8.0   300.0  81.0
# 4          5  2013      3    1     4    3.0   3.0  14.0   8.0   300.0  81.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 35059  35060  2017      2   28    19   16.0  51.0   3.0  29.0   400.0  73.0
# 35060  35061  2017      2   28    20   18.0  45.0   3.0  43.0   500.0  54.0
# 35061  35062  2017      2   28    21   23.0  58.0   5.0  61.0   700.0  28.0
# 35062  35063  2017      2   28    22   23.0  53.0   9.0  75.0   900.0  15.0
# 35063  35064  2017      2   28    23   30.0  71.0  11.0  87.0  1200.0   4.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 0      -2.3  1020.8 -19.7   0.0    E   0.5  Changping
# 1      -2.5  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2      -3.0  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3      -3.6  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4      -3.5  1022.3 -19.4   0.0    N   2.1  Changping
# ...     ...     ...   ...   ...  ...   ...        ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4     Dongsi
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9     Dongsi
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1     Dongsi
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2     Dongsi
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3     Dongsi
#
# [63773 rows x 18 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# - Melakukan analisis deskriptif statistik pada dataset untuk mendapatkan gambaran umum distribusi data, seperti mean, median, mode, standar deviasi, dan kuartil variabel
# - RFM analysis untuk trend kadar PM10 berdasarkan waktu (monthly)
# - Menganalisis korelasi antara kualitas udara dan suhu

# %% [markdown]
# ### Explore Data Stasiun Changping

# %% [markdown]
# 1. Menghitung statistik deskriptif dari dataframe Changbing_df mencakup informasi ringkasan berbagai nilai statistik seperti jumlah, mean (rata-rata), standar deviasi, nilai minimum, kuartil, dan nilai maksimum untuk setiap kolom dalam DataFrame tersebut.

# %%
descriptive_stats = Changping_df.describe()
print(descriptive_stats)
# Out:
#                  No          year         month           day         hour  \
# count  31543.000000  31543.000000  31543.000000  31543.000000  31543.00000
# mean   17685.928447   2014.674698      6.586025     15.789272     11.34686
# std    10141.750717      1.180994      3.371876      8.790988      7.00736
# min        1.000000   2013.000000      1.000000      1.000000      0.00000
# 25%     9123.000000   2014.000000      4.000000      8.000000      5.00000
# 50%    17922.000000   2015.000000      7.000000     16.000000     11.00000
# 75%    26538.500000   2016.000000      9.000000     23.000000     18.00000
# max    35064.000000   2017.000000     12.000000     31.000000     23.00000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  31543.000000  31543.000000  31543.000000  31543.000000  31543.000000
# mean      61.615514     82.805297     12.388254     41.835175   1001.976926
# std       57.216222     64.214960     14.978145     25.796885    772.615810
# min        2.000000      2.000000      0.290000      1.850000    100.000000
# 25%       17.000000     32.000000      2.000000     22.000000    500.000000
# 50%       42.000000     66.000000      6.000000     36.000000    733.330000
# 75%       89.000000    119.000000     16.000000     57.000000   1300.000000
# max      288.000000    346.000000     77.000000    132.000000   4500.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  31543.000000  31543.000000  31543.000000  31543.000000  31543.000000
# mean      55.792673     13.957873   1007.658507      1.798047      0.021238
# std       47.261131     11.125831     10.170717     13.797963      0.151069
# min        0.210000    -16.600000    982.400000    -35.100000      0.000000
# 25%       18.000000      4.000000    999.300000    -10.100000      0.000000
# 50%       47.000000     15.200000   1007.100000      2.600000      0.000000
# 75%       79.000000     23.300000   1015.900000     14.400000      0.000000
# max      220.200000     41.400000   1036.500000     27.200000      2.300000
#
#                WSPM
# count  31543.000000
# mean       1.769221
# std        1.140515
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.200000
# max        5.700000

# %% [markdown]
# 2. Menampilkan 5 data dari bagian awal, tengah, serta akhir dataframe untuk validasi pemahaman akan data

# %%
print(Changping_df.head())
print(Changping_df.tail())
print(Changping_df.info())
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 35059  35060  2017      2   28    19   28.0  47.0  4.0  14.0  300.0  33.0
# 35060  35061  2017      2   28    20   12.0  12.0  3.0  23.0  500.0  64.0
# 35061  35062  2017      2   28    21    7.0  23.0  5.0  17.0  500.0  68.0
# 35062  35063  2017      2   28    22   11.0  20.0  3.0  15.0  500.0  72.0
# 35063  35064  2017      2   28    23   20.0  25.0  6.0  28.0  900.0  54.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 35059  11.7  1008.9 -13.3   0.0  NNE   1.3  Changping
# 35060  10.9  1009.0 -14.0   0.0    N   2.1  Changping
# 35061   9.5  1009.4 -13.0   0.0    N   1.5  Changping
# 35062   7.8  1009.6 -12.6   0.0   NW   1.4  Changping
# 35063   7.0  1009.4 -12.2   0.0    N   1.9  Changping
# <class 'pandas.core.frame.DataFrame'>
# Index: 31543 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       31543 non-null  int64
#  1   year     31543 non-null  int64
#  2   month    31543 non-null  int64
#  3   day      31543 non-null  int64
#  4   hour     31543 non-null  int64
#  5   PM2.5    31543 non-null  float64
#  6   PM10     31543 non-null  float64
#  7   SO2      31543 non-null  float64
#  8   NO2      31543 non-null  float64
#  9   CO       31543 non-null  float64
#  10  O3       31543 non-null  float64
#  11  TEMP     31543 non-null  float64
#  12  PRES     31543 non-null  float64
#  13  DEWP     31543 non-null  float64
#  14  RAIN     31543 non-null  float64
#  15  wd       31418 non-null  object
#  16  WSPM     31543 non-null  float64
#  17  station  31543 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.6+ MB
# None

# %% [markdown]
# 3. Mempelajari tren nilai mean dari fitur PM10 pada setiap bulannya di Stasiun Changping pada tahun 2015

# %%
# Filter data untuk tahun 2015
Changping_df_2015 = Changping_df[Changping_df['year'] == 2015]

# Hitung rata-rata PM10 untuk setiap bulan
monthly_avg_pm10 = Changping_df_2015.groupby('month')['PM10'].mean()

# Plot rata-rata PM10 per bulan
plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_avg_pm10.index, y=monthly_avg_pm10.values, marker='o', color='navy')
plt.title('Rata-rata PM10 per Bulan pada Tahun 2015 di Stasiun Changping')
plt.xlabel('Bulan')
plt.ylabel('Rata-rata PM10')
plt.show()

# %% [markdown]
# 4. Melihat distribusi frekuensi data yang diwakili sumbu x menunjukkan nilai PM10, sedangkan sumbu y menunjukkan frekuensi berapa kali nilai-nilai tersebut muncul dalam dataframe Stasiun Changping pada tahun 2015.

# %%
plt.hist(Changping_df_2015['PM10'], bins=20, color='#001F3F', alpha=0.7, edgecolor='#808080', linewidth=1.2)
plt.title('Distribusi PM10')
plt.xlabel('PM10')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# 5. Baris program ini menghitung RFQ (Recency, Frequency, Quality) analisis dari data PM10 untuk stasiun Changping.
#     - Recency: Menghitung bulan terbaru dalam data.
#     - Frequency: Menghitung jumlah pengamatan PM10 yang diukur dalam setiap bulan.
#     - Quality: Menghitung rata-rata PM10 dalam setiap bulan.

# %%
# Menghitung Recency (bulan terbaru)
recency = Changping_df['month'].max()

# Menghitung Frequency (jumlah kali {PM10} diukur dalam setiap bulan)
frequency = Changping_df.groupby('month')['PM10'].size()  # Menggunakan size() untuk menghitung jumlah pengamatan

# Menghitung Quality (rata-rata {PM10} dalam setiap bulan)
quality = Changping_df.groupby('month')['PM10'].mean()

# Menggabungkan hasil analisis RFQ ke dalam satu DataFrame
rfq_analysis = pd.DataFrame({
    'Recency': recency,
    'Frequency': frequency,
    'Quality': quality
})

print(rfq_analysis)
# Out:
#        Recency  Frequency     Quality
# month
# 1           12       2332   77.921484
# 2           12       2300   74.126739
# 3           12       2673  112.756341
# 4           12       2725  103.130826
# 5           12       2714   89.113965
# 6           12       2685   71.993929
# 7           12       2674   72.221765
# 8           12       2784   58.937284
# 9           12       2803   66.248484
# 10          12       2793   88.794629
# 11          12       2655   95.091714
# 12          12       2405   82.647019

# %% [markdown]
# ### Explore Data Stasiun Dongsi

# %% [markdown]
# ##### Melakukan perhitungan statistik deskriptif

# %% [markdown]
# 1. Menghitung statistik deskriptif dari dataframe Dongsi_df mencakup informasi ringkasan berbagai nilai statistik seperti jumlah, mean (rata-rata), standar deviasi, nilai minimum, kuartil, dan nilai maksimum untuk setiap kolom dalam DataFrame tersebut.

# %%
descriptive_stats = Dongsi_df.describe()
print(descriptive_stats)
# Out:
#                  No          year         month           day          hour  \
# count  32230.000000  32230.000000  32230.000000  32230.000000  32230.000000
# mean   17687.135991   2014.678684      6.541111     15.741669     11.433913
# std    10094.407870      1.176904      3.385036      8.780369      6.919534
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9167.250000   2014.000000      4.000000      8.000000      5.000000
# 50%    17804.500000   2015.000000      7.000000     16.000000     11.000000
# 75%    26505.750000   2016.000000      9.000000     23.000000     17.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  32230.000000  32230.000000  32230.000000  32230.000000  32230.000000
# mean      75.869120     97.586922     16.041079     51.559929   1186.614086
# std       67.423877     75.568640     17.354611     30.128017    844.092356
# min        3.000000      2.000000      0.290000      2.000000    100.000000
# 25%       22.000000     36.000000      3.000000     28.000000    600.000000
# 50%       57.000000     81.000000      9.000000     46.000000    965.710000
# 75%      109.000000    139.000000     22.000000     71.000000   1500.000000
# max      344.000000    405.000000     87.000000    156.000000   4800.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  32230.000000  32230.000000  32230.000000  32230.000000  32230.000000
# mean      56.838655     14.052753   1012.462764      2.730915      0.020515
# std       51.465805     11.329020     10.309429     13.899340      0.151292
# min        0.640000    -16.800000    987.100000    -35.300000      0.000000
# 25%       14.000000      3.900000   1003.900000     -8.800000      0.000000
# 50%       46.000000     15.300000   1012.000000      3.900000      0.000000
# 75%       82.000000     23.700000   1020.800000     15.300000      0.000000
# max      232.620000     41.100000   1042.000000     28.800000      2.400000
#
#                WSPM
# count  32230.000000
# mean       1.805299
# std        1.130265
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max        5.700000

# %% [markdown]
# 2. Menampilkan 5 data dari bagian awal, tengah, serta akhir dataframe untuk validasi pemahaman akan data

# %%
print(Dongsi_df.head())
print(Dongsi_df.tail())
print(Dongsi_df.info())
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  4.0  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0  250.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0  21.5  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 35059  35060  2017      2   28    19   16.0  51.0   3.0  29.0   400.0  73.0
# 35060  35061  2017      2   28    20   18.0  45.0   3.0  43.0   500.0  54.0
# 35061  35062  2017      2   28    21   23.0  58.0   5.0  61.0   700.0  28.0
# 35062  35063  2017      2   28    22   23.0  53.0   9.0  75.0   900.0  15.0
# 35063  35064  2017      2   28    23   30.0  71.0  11.0  87.0  1200.0   4.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Dongsi
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Dongsi
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Dongsi
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Dongsi
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Dongsi
# <class 'pandas.core.frame.DataFrame'>
# Index: 32230 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       32230 non-null  int64
#  1   year     32230 non-null  int64
#  2   month    32230 non-null  int64
#  3   day      32230 non-null  int64
#  4   hour     32230 non-null  int64
#  5   PM2.5    32230 non-null  float64
#  6   PM10     32230 non-null  float64
#  7   SO2      32230 non-null  float64
#  8   NO2      32230 non-null  float64
#  9   CO       32230 non-null  float64
#  10  O3       32230 non-null  float64
#  11  TEMP     32230 non-null  float64
#  12  PRES     32230 non-null  float64
#  13  DEWP     32230 non-null  float64
#  14  RAIN     32230 non-null  float64
#  15  wd       32157 non-null  object
#  16  WSPM     32230 non-null  float64
#  17  station  32230 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.7+ MB
# None

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana perubahan kondisi kualitas udara berdasarkan data PM10 pada setiap bulannya di tahun 2015 yang terjadi di Stasiun Changping?

# %% [markdown]
# 1.1. Memvisualisasikan hasil analisis RFQ divisualisasikan dalam bar chart, menunjukkan frekuensi pengukuran PM10 per bulan.

# %%
# Visualisasi Frekuensi PM10 per Bulan
plt.figure(figsize=(10, 6))
sns.barplot(data=rfq_analysis, x=rfq_analysis.index, y='Frequency', color='#001F3F')
plt.title('Frekuensi PM10 per Bulan 2015 di Changping')
plt.xlabel('Bulan')
plt.ylabel('Frekuensi')

# Mengubah label bulan menjadi nama bulan
plt.xticks(ticks=range(12), labels=[calendar.month_name[i] for i in range(1, 13)], rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1.2 Memvisualisasikan rata-rata tingkat PM10 per bulan pada tahun 2015 di stasiun Changping.

# %%
# Visualisasi Rata-rata PM2.5 per Bulan
plt.figure(figsize=(10, 6))
sns.barplot(data=rfq_analysis, x=rfq_analysis.index, y='Quality', color='#001F3F')
plt.title('Rata-rata PM10 per Bulan 2015 di Changping')
plt.xlabel('Bulan')
plt.ylabel('Rata-rata PM2.5')

# Mengubah label bulan menjadi nama bulan
plt.xticks(ticks=range(12), labels=[calendar.month_name[i] for i in range(1, 13)], rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1.3 Memvisualisasikan perubahan kualitas udara seiring waktu, khususnya perubahan rata-rata PM10 per bulan pada tahun 2015 di stasiun pengukuran udara Changping.

# %%
# Visualisasi Perubahan Kualitas Udara Seiring Waktu
plt.figure(figsize=(10, 6))
sns.lineplot(data=rfq_analysis, x=rfq_analysis.index, y='Quality', marker='o', color='navy')
plt.title('Perubahan Kualitas Udara Seiring Waktu di Changping 2015')
plt.xlabel('Bulan')
plt.ylabel('Kualitas Udara')

# Mengubah label bulan menjadi nama bulan
plt.xticks(ticks=range(12), labels=[calendar.month_name[i] for i in range(1, 13)], rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1.4 Menggunakan Plot tren bulanan lalu mencari nilai tertinggi dan terendah dari rata-rata PM10

# %%
# Hitung rata-rata PM10 untuk setiap bulan
monthly_avg_pm10 = Changping_df_2015.groupby('month')['PM10'].mean()

# Temukan bulan dengan rata-rata PM10 tertinggi dan terendah
bulan_tertinggi = monthly_avg_pm10.idxmax()
nilai_tertinggi = monthly_avg_pm10.max()
bulan_terendah = monthly_avg_pm10.idxmin()
nilai_terendah = monthly_avg_pm10.min()

# Buat plot tren bulanan
plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_avg_pm10.index, y=monthly_avg_pm10.values, marker='o', color='navy')
plt.title('Tren Rata-rata PM10 per Bulan di Changping 2015')
plt.xlabel('Bulan')
plt.ylabel('Rata-rata PM10')

# Tambahkan titik untuk data tertinggi dan terendah dengan penyesuaian ukuran dan warna
plt.scatter(x=bulan_tertinggi, y=nilai_tertinggi, color='red', label=f'Tertinggi: {nilai_tertinggi:.2f}', s=100, edgecolor='black', linewidth=1.5)
plt.scatter(x=bulan_terendah, y=nilai_terendah, color='green', label=f'Terendah: {nilai_terendah:.2f}', s=100, edgecolor='black', linewidth=1.5)

# Tampilkan legenda
plt.legend()

# Mengubah label bulan menjadi nama bulan
plt.xticks(ticks=range(1, 13), labels=[calendar.month_name[i] for i in range(1, 13)], rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana perbandingan kadar karbon monoksida pada udara di Stasiun Changping dan Stasiun Dongsi

# %% [markdown]
# 2.1 Menghitung rata-rata kadar CO di dua stasiun pengukuran udara, yaitu Changping dan Dongsi, dan kemudian memvisualisasikan perbandingan rata-rata kadar CO.

# %%
# Menghitung rata-rata CO
mean_co_changping = Changping_df['CO'].mean()
mean_co_dongsi = Dongsi_df['CO'].mean()

# Visualisasi perbandingan rata-rata CO
plt.figure(figsize=(8, 6))
plt.bar(['Changping', 'Dongsi'], [mean_co_changping, mean_co_dongsi], color=['blue', 'green'])
plt.title('Perbandingan Rata-rata Kadar CO di Changping dan Dongsi')
plt.xlabel('Stasiun')
plt.ylabel('Rata-rata Kadar CO')
plt.show()

# %% [markdown]
# 2.2 Memvisualisasikan distribusi frekuensi kadar CO di masing-masing stasiun untuk memahami variasi dalam kualitas udara di dua lokasi yang berbeda.

# %%
# Visualisasi distribusi CO menggunakan histogram
plt.figure(figsize=(10, 6))
plt.hist(Changping_df['CO'], bins=30, alpha=0.5, label='Changping', color='blue')
plt.hist(Dongsi_df['CO'], bins=30, alpha=0.5, label='Dongsi', color='green')
plt.title('Distribusi Kadar CO di Changping dan Dongsi')
plt.xlabel('Kadar CO')
plt.ylabel('Frekuensi')
plt.legend()
plt.show()

# %% [markdown]
# 2.3 Mengelompokkan data per tahun dan menghitung rata-rata kadar CO untuk masing-masing stasiun (Changping dan Dongsi). Memvisualisasikan tren waktu per tahun dari rata-rata kadar CO di kedua stasiun, Changping dan Dongsi.

# %%
# Mengubah kolom 'year', 'month', dan 'day' menjadi tipe data datetime
Changping_df['date'] = pd.to_datetime(Changping_df[['year', 'month', 'day']])
Dongsi_df['date'] = pd.to_datetime(Dongsi_df[['year', 'month', 'day']])

# Mengelompokkan data per tahun dan menghitung rata-rata CO
Changping_yearly = Changping_df.groupby(Changping_df['date'].dt.year)['CO'].mean()
Dongsi_yearly = Dongsi_df.groupby(Dongsi_df['date'].dt.year)['CO'].mean()

# Visualisasi tren waktu per tahun
plt.figure(figsize=(12, 6))
plt.plot(Changping_yearly.index, Changping_yearly.values, label='Changping', color='blue', marker='o')
plt.plot(Dongsi_yearly.index, Dongsi_yearly.values, label='Dongsi', color='green', marker='o')
plt.title('Tren Waktu Kadar Rata-rata CO di Changping dan Dongsi (per Tahun)')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata Kadar CO')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pertanyaan 3: Bagaimana hubungan antara tingkat polusi udara (diwakili oleh PM2.5 dan PM10) dengan suhu udara (TEMP) pada bulan September 2014 hingga Juni 2015 pada Stasiun Dongsi

# %% [markdown]
# 3.1 Memvisualisasikan hubungan antara temperatur dan tingkat polusi udara (PM2.5 dan PM10) di stasiun Dongsi selama periode tertentu, membantu dalam memahami dampak temperatur terhadap kualitas udara pada rentang waktu yang ditentukan.

# %%
start_date = '2014-11-01'
end_date = '2015-01-28'  # Mengubah 30 menjadi 28 karena Februari hanya memiliki 28 hari
filtered_df = Dongsi_df[(Dongsi_df['date'] >= start_date) & (Dongsi_df['date'] <= end_date)]

plt.figure(figsize=(12, 6))
sns.scatterplot(x='TEMP', y='PM2.5', data=filtered_df, color='blue')
plt.title('Korelasi antara PM2.5 dan Temperatur (Sept 2014 - Jun 2015)')
plt.xlabel('Temperatur (°C)')
plt.ylabel('PM2.5')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
sns.scatterplot(x='TEMP', y='PM10', data=filtered_df, color='blue')
plt.title('Korelasi antara PM10 dan Temperatur (Sept 2014 - Jun 2015)')
plt.xlabel('Temperatur (°C)')
plt.ylabel('PM10')
plt.grid(True)
plt.show()

# %% [markdown]
# 3.2 Memvisualisasikan perubahan seiring waktu dalam tingkat polusi udara PM2.5 dan PM10 terhadap temperatur di stasiun Dongsi

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='PM2.5', data=filtered_df, alpha=0.5)
plt.title('Tren PM2.5 (Sept 2014 - Jun 2015)')
plt.xlabel('Tanggal')
plt.ylabel('PM2.5')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='PM10', data=filtered_df, alpha=0.5)
plt.title('Tren PM10 (Sept 2014 - Jun 2015)')
plt.xlabel('Tanggal')
plt.ylabel('PM10')
plt.grid(True)
plt.show()

# %% [markdown]
# 3.3  Memvisualisasikan hubungan antara tingkat polusi udara (PM2.5 dan PM10) dengan suhu udara selama rentang waktu tertentu (September 2014 hingga Juni 2015) di stasiun Dongsi.

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='TEMP', y='PM2.5', data=filtered_df, label='PM2.5', alpha=0.5)
sns.scatterplot(x='TEMP', y='PM10', data=filtered_df, label='PM10', alpha=0.5)
plt.title('Hubungan antara Tingkat Polusi Udara dengan Suhu Udara (Sept 2014 - Jun 2015)')
plt.xlabel('Suhu Udara (°C)')
plt.ylabel('Tingkat Polusi Udara (PM2.5 / PM10)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 3.4 Menghitung matriks korelasi antara variabel PM2.5, PM10, dan suhu udara (TEMP) dari DataFrame yang telah difilter (filtered_df).

# %%
correlation_matrix = filtered_df[['PM2.5', 'PM10', 'TEMP']].corr()

print("Correlation Matrix:")
print(correlation_matrix)

# Visualisasi correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='twilight', fmt=".2f")
plt.title('Correlation Matrix antara PM2.5, PM10, dan Temperatur')
plt.show()
# Out:
# Correlation Matrix:
#           PM2.5      PM10      TEMP
# PM2.5  1.000000  0.929506 -0.147715
# PM10   0.929506  1.000000 -0.098911
# TEMP  -0.147715 -0.098911  1.000000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Berdasarkan analisis Data tersebut, dapat diketahui bahwa terdapat perubahan kondisi kualitas udara yang cukup signifikan pada data PM10 di setiap bulannya pada tahun 2015 di Stasiun Changping. Kualitas udara terendah terjadi pada bulan Maret 2015 dan kualitas udara terbaik terjadi pada bulan Agustus 2015. Selanjutnya data dapat dianalis lebih lanjut dengan parameter lain seperti fitur Rain untuk mencari tahu korelasi sebagai salah satu kemungkinan penyebab tinggi rendahnya kualitas udara
#
# - Berdasarkan visualisasi dan analisis data, dapat diketahui bahwa kadar CO atau karbon monoksida di Stasiun Changping dan Stasiun Dongsi memiliki perbedaan yang cukup jauh pada tahun 2013, namun semakin rendah perbedaanya pada thaun 2017.
#
# - Korelasi atau hubungan antara kualitas udara yang direpresentasikan dengan fitur PM2.5 dan PM10 terhadap temperatur menunjukkan hubungan korelasi negative.
